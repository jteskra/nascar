# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
import pandas as pd
from scipy import stats
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
import warnings
warnings.filterwarnings('ignore')
from imblearn.over_sampling import SMOTE
from sklearn.ensemble import IsolationForest
from sklearn.svm import OneClassSVM
import matplotlib.pyplot as plt
import joblib
import numpy as np
import psycopg2
from sqlalchemy import create_engine, text
import json
from sklearn.preprocessing import LabelEncoder
from imblearn.over_sampling import BorderlineSMOTE
from sklearn.metrics import accuracy_score, mean_squared_error

# %%
# Read the CSV file into a Pandas DataFrame
# This reads the first sheet by default
# df = pd.read_excel('master_nascar_copy_2.xlsx')
# Read all sheets into a dictionary of DataFrames
df = pd.read_excel('master_nascar_copy_2.xlsx', sheet_name='2022-2023')

# Concatenate all DataFrames in the dictionary into a single DataFrame
# df = pd.concat(all_sheets.values(), ignore_index=True)



# df = pd.read_csv('master_nascar_copy.csv')
# df.dropna(subset=df.columns, inplace=True)
# Review the DataFrame
# df.head(10)

# %%
# for index, row in df.iterrows():
#     print(row['Team'])

# %%
df = df.iloc[:-5]

# %%
replace_map = {
    'running': 1,
    'accident': 2,
    'electrical': 3,
    'engine': 4,
    'DVP': 5,
    'NaN': 6,
    'drivetrain':7,
    'fuel pump':8,
    'rear gear':9,
    'suspension':10,
    'brakes':11,
    'throttle':12,
    'power steering':13,
    'water pump':14,
    'exhaust':15,
    'steering':16,
    'fire':17,
    'driveshaft':18,
    'handling':19,
    'fuel':20,
    'chassis':21,
    'rear end':22,
    'overheating':23
}

df['Status'] = df['Status'].replace(replace_map)
df['Status.1'] = df['Status.1'].replace(replace_map)
df['Status.2'] = df['Status.2'].replace(replace_map)
df['Status.3'] = df['Status.3'].replace(replace_map)
df['Status.4'] = df['Status.4'].replace(replace_map)
df['Status.5'] = df['Status.5'].replace(replace_map)
df['Status.6'] = df['Status.6'].replace(replace_map)
df['Status.7'] = df['Status.7'].replace(replace_map)
df['Status.8'] = df['Status.8'].replace(replace_map)
df['Status.9'] = df['Status.9'].replace(replace_map)
df['Status.10'] = df['Status.10'].replace(replace_map)
df['Status.11'] = df['Status.11'].replace(replace_map)
df['Status.12'] = df['Status.12'].replace(replace_map)
df['Status.13'] = df['Status.13'].replace(replace_map)
df['Status.14'] = df['Status.14'].replace(replace_map)
df['Status.15'] = df['Status.15'].replace(replace_map)
df['Status.16'] = df['Status.16'].replace(replace_map)
df['Status.17'] = df['Status.17'].replace(replace_map)
df['Status.18'] = df['Status.18'].replace(replace_map)
df['Status.19'] = df['Status.19'].replace(replace_map)
df['Status.20'] = df['Status.20'].replace(replace_map)
df['Status.21'] = df['Status.21'].replace(replace_map)
df['Status.22'] = df['Status.22'].replace(replace_map)
df['Status.23'] = df['Status.23'].replace(replace_map)
df['Status.24'] = df['Status.24'].replace(replace_map)
df['Status.25'] = df['Status.25'].replace(replace_map)
df['Status.26'] = df['Status.26'].replace(replace_map)
df['Status.27'] = df['Status.27'].replace(replace_map)
df['Status.28'] = df['Status.28'].replace(replace_map)
df['Status.29'] = df['Status.29'].replace(replace_map)
df['Status.30'] = df['Status.30'].replace(replace_map)
df['Status.31'] = df['Status.31'].replace(replace_map)
df['Status.32'] = df['Status.32'].replace(replace_map)
df['Status.33'] = df['Status.33'].replace(replace_map)
df['Status.34'] = df['Status.34'].replace(replace_map)
df['Status.35'] = df['Status.35'].replace(replace_map)
df['Status.36'] = df['Status.36'].replace(replace_map)
df['Status.37'] = df['Status.37'].replace(replace_map)
df['Status.38'] = df['Status.38'].replace(replace_map)
df['Status.39'] = df['Status.39'].replace(replace_map)
df['Status.40'] = df['Status.40'].replace(replace_map)
df['Status.41'] = df['Status.41'].replace(replace_map)
df['Status.42'] = df['Status.42'].replace(replace_map)
df['Status.43'] = df['Status.43'].replace(replace_map)
df['Status.44'] = df['Status.44'].replace(replace_map)
df['Status.45'] = df['Status.45'].replace(replace_map)
df['Status.46'] = df['Status.46'].replace(replace_map)
df['Status.47'] = df['Status.47'].replace(replace_map)
df['Status.48'] = df['Status.48'].replace(replace_map)
df['Status.49'] = df['Status.49'].replace(replace_map)
df['Status.50'] = df['Status.50'].replace(replace_map)
df['Status.51'] = df['Status.51'].replace(replace_map)
df['Status.52'] = df['Status.52'].replace(replace_map)
df['Status.53'] = df['Status.53'].replace(replace_map)
df['Status.54'] = df['Status.54'].replace(replace_map)
df['Status.55'] = df['Status.55'].replace(replace_map)
df['Status.56'] = df['Status.56'].replace(replace_map)
df['Status.57'] = df['Status.57'].replace(replace_map)
df['Status.58'] = df['Status.58'].replace(replace_map)
df['Status.59'] = df['Status.59'].replace(replace_map)
df['Status.60'] = df['Status.60'].replace(replace_map)
df['Status.61'] = df['Status.61'].replace(replace_map)
df['Status.62'] = df['Status.62'].replace(replace_map)
df['Status.63'] = df['Status.63'].replace(replace_map)
df['Status.64'] = df['Status.64'].replace(replace_map)
df['Status.65'] = df['Status.65'].replace(replace_map)
df['Status.66'] = df['Status.66'].replace(replace_map)




# df

# %%
# df

# %%
replace_map = {
    'Ford': 1,
    'Toyota': 2,
    'Chevrolet': 3,

}

df['Make'] = df['Make'].replace(replace_map)
df['Make.1'] = df['Make.1'].replace(replace_map)
df['Make.2'] = df['Make.2'].replace(replace_map)
df['Make.3'] = df['Make.3'].replace(replace_map)
df['Make.4'] = df['Make.4'].replace(replace_map)
df['Make.5'] = df['Make.5'].replace(replace_map)
df['Make.6'] = df['Make.6'].replace(replace_map)
df['Make.7'] = df['Make.7'].replace(replace_map)
df['Make.8'] = df['Make.8'].replace(replace_map)
df['Make.9'] = df['Make.9'].replace(replace_map)
df['Make.10'] = df['Make.10'].replace(replace_map)
df['Make.11'] = df['Make.11'].replace(replace_map)
df['Make.12'] = df['Make.12'].replace(replace_map)
df['Make.13'] = df['Make.13'].replace(replace_map)
df['Make.14'] = df['Make.14'].replace(replace_map)
df['Make.15'] = df['Make.15'].replace(replace_map)
df['Make.16'] = df['Make.16'].replace(replace_map)
df['Make.17'] = df['Make.17'].replace(replace_map)
df['Make.18'] = df['Make.18'].replace(replace_map)
df['Make.19'] = df['Make.19'].replace(replace_map)
df['Make.20'] = df['Make.20'].replace(replace_map)
df['Make.21'] = df['Make.21'].replace(replace_map)
df['Make.22'] = df['Make.22'].replace(replace_map)
df['Make.23'] = df['Make.23'].replace(replace_map)
df['Make.24'] = df['Make.24'].replace(replace_map)
df['Make.25'] = df['Make.25'].replace(replace_map)
df['Make.26'] = df['Make.26'].replace(replace_map)
df['Make.27'] = df['Make.27'].replace(replace_map)
df['Make.28'] = df['Make.28'].replace(replace_map)
df['Make.29'] = df['Make.29'].replace(replace_map)
df['Make.30'] = df['Make.30'].replace(replace_map)
df['Make.31'] = df['Make.31'].replace(replace_map)
df['Make.32'] = df['Make.32'].replace(replace_map)
df['Make.33'] = df['Make.33'].replace(replace_map)
df['Make.34'] = df['Make.34'].replace(replace_map)
df['Make.35'] = df['Make.35'].replace(replace_map)
df['Make.36'] = df['Make.36'].replace(replace_map)
df['Make.37'] = df['Make.37'].replace(replace_map)
df['Make.38'] = df['Make.38'].replace(replace_map)
df['Make.39'] = df['Make.39'].replace(replace_map)
df['Make.40'] = df['Make.40'].replace(replace_map)
df['Make.41'] = df['Make.41'].replace(replace_map)
df['Make.42'] = df['Make.42'].replace(replace_map)
df['Make.43'] = df['Make.43'].replace(replace_map)
df['Make.44'] = df['Make.44'].replace(replace_map)
df['Make.45'] = df['Make.45'].replace(replace_map)
df['Make.46'] = df['Make.46'].replace(replace_map)
df['Make.47'] = df['Make.47'].replace(replace_map)
df['Make.48'] = df['Make.48'].replace(replace_map)
df['Make.49'] = df['Make.49'].replace(replace_map)
df['Make.50'] = df['Make.50'].replace(replace_map)
df['Make.51'] = df['Make.51'].replace(replace_map)
df['Make.52'] = df['Make.52'].replace(replace_map)
df['Make.53'] = df['Make.53'].replace(replace_map)
df['Make.54'] = df['Make.54'].replace(replace_map)
df['Make.55'] = df['Make.55'].replace(replace_map)
df['Make.56'] = df['Make.56'].replace(replace_map)
df['Make.57'] = df['Make.57'].replace(replace_map)
df['Make.58'] = df['Make.58'].replace(replace_map)
df['Make.59'] = df['Make.59'].replace(replace_map)
df['Make.60'] = df['Make.60'].replace(replace_map)
df['Make.61'] = df['Make.61'].replace(replace_map)
df['Make.62'] = df['Make.62'].replace(replace_map)
df['Make.63'] = df['Make.63'].replace(replace_map)
df['Make.64'] = df['Make.64'].replace(replace_map)
df['Make.65'] = df['Make.65'].replace(replace_map)
df['Make.66'] = df['Make.66'].replace(replace_map)


# df.head(10)

# %%
replace_map = {
    "Alex Bowman": 1,
    "Aric Almirola": 2, 
    "Austin Cindric": 3, 
    "Austin Dillon": 4,
    "B.J. McLeod": 5, 
    "Brad Keselowski": 6, 
    "Chase Briscoe": 7, 
    "Chase Elliott":8, 
    "Chris Buescher":9,
    "Christopher Bell":10, 
    "Cody Ware":11,
    "Cole Custer":12, 
    "Corey LaJoie":13, 
    "Daniel Hemric":14,
    "Daniel Suarez":15,
    "Darrell Wallace Jr.":16, 
    "David Ragan":17, 
    "Erik Jones":18, 
    "Greg Biffle":19,
    "Jacques Villeneuve":20, 
    "Joey Logano":21, 
    "Justin Haley":22, 
    "Kaz Grala":23, 
    "Kevin Harvick":24, 
    "Kyle Busch":25, 
    "Kyle Larson":26, 
    "Landon Cassill":27, 
    "Martin Truex Jr.":28,
    "Michael McDowell":29, 
    "Noah Gragson":30, 
    "Ricky Stenhouse Jr.":31,
    "Ryan Blaney":32, 
    "Todd Gilliland":33, 
    "Tyler Reddick":34, 
    "Ty Dillon":35,
    "Kurt Busch":36,
    "Denny Hamlin":37,
    "Garrett Smithley":38,
    'Ross Chastain':39,
    'Josh Bilicki':40,
    'Harrison Burton':41,
    'William Byron':42,
    'A.J. Allmendinger':43,
    'Boris Said':44,
    'Loris Hezemans':45,
    'Joey Hand':46,
    'J.J. Yeley':47,
    'Josh Williams':48,
    'Ryan Preece':49,
    'Zane Smith':50,
    'Parker Kligerman':51,
    'Scott Heckert':52,
    'Kyle Tilley':53,
    'Ty Gibbs':54,
    'Austin Hill':55,
    'Mike Rockenfeller':56,
    'Justin Allgaier':57,
    'Conor Daly':58,
    'John Hunter Nemechek':59,
    'Riley Herbst':60,
    'Travis Pastrana':61,
    'Jimmie Johnson':62,
    'Josh Berry':63,
    'Andy Lally':64,
    'Jenson Button':65,
    'Jordan Taylor':66,
    'Kimi Raikkonen':67,
    'Chandler Smith':68,
    'Anthony Alfredo':69,
    'Matt Crafton':70,
    'Brennan Poole':71,
    'Ryan Newman':72,
    'Gray Gaulding':73,
    'Grant Enfinger':74,
    'Shane van Gisbergen':75,
    'Daniil Kvyat':76,
    'Brodie Kostecki':77,
    'Kamui Kobayashi':78,
    'Carson Hocevar':79,
    'Sheldon Creed':80
}


df['Driver'] = df['Driver'].replace(replace_map)
df['Driver.1'] = df['Driver.1'].replace(replace_map)
df['Driver.2'] = df['Driver.2'].replace(replace_map)
df['Driver.3'] = df['Driver.3'].replace(replace_map)
df['Driver.4'] = df['Driver.4'].replace(replace_map)
df['Driver.5'] = df['Driver.5'].replace(replace_map)
df['Driver.6'] = df['Driver.6'].replace(replace_map)
df['Driver.7'] = df['Driver.7'].replace(replace_map)
df['Driver.8'] = df['Driver.8'].replace(replace_map)
df['Driver.9'] = df['Driver.9'].replace(replace_map)
df['Driver.10'] = df['Driver.10'].replace(replace_map)
df['Driver.11'] = df['Driver.11'].replace(replace_map)
df['Driver.12'] = df['Driver.12'].replace(replace_map)
df['Driver.13'] = df['Driver.13'].replace(replace_map)
df['Driver.14'] = df['Driver.14'].replace(replace_map)
df['Driver.15'] = df['Driver.15'].replace(replace_map)
df['Driver.16'] = df['Driver.16'].replace(replace_map)
df['Driver.17'] = df['Driver.17'].replace(replace_map)
df['Driver.18'] = df['Driver.18'].replace(replace_map)
df['Driver.19'] = df['Driver.19'].replace(replace_map)
df['Driver.20'] = df['Driver.20'].replace(replace_map)
df['Driver.21'] = df['Driver.21'].replace(replace_map)
df['Driver.22'] = df['Driver.22'].replace(replace_map)
df['Driver.23'] = df['Driver.23'].replace(replace_map)
df['Driver.24'] = df['Driver.24'].replace(replace_map)
df['Driver.25'] = df['Driver.25'].replace(replace_map)
df['Driver.26'] = df['Driver.26'].replace(replace_map)
df['Driver.27'] = df['Driver.27'].replace(replace_map)
df['Driver.28'] = df['Driver.28'].replace(replace_map)
df['Driver.29'] = df['Driver.29'].replace(replace_map)
df['Driver.30'] = df['Driver.30'].replace(replace_map)
df['Driver.31'] = df['Driver.31'].replace(replace_map)
df['Driver.32'] = df['Driver.32'].replace(replace_map)
df['Driver.33'] = df['Driver.33'].replace(replace_map)
df['Driver.34'] = df['Driver.34'].replace(replace_map)
df['Driver.35'] = df['Driver.35'].replace(replace_map)
df['Driver.36'] = df['Driver.36'].replace(replace_map)
df['Driver.37'] = df['Driver.37'].replace(replace_map)
df['Driver.38'] = df['Driver.38'].replace(replace_map)
df['Driver.39'] = df['Driver.39'].replace(replace_map)
df['Driver.40'] = df['Driver.40'].replace(replace_map)
df['Driver.41'] = df['Driver.41'].replace(replace_map)
df['Driver.42'] = df['Driver.42'].replace(replace_map)
df['Driver.43'] = df['Driver.43'].replace(replace_map)
df['Driver.44'] = df['Driver.44'].replace(replace_map)
df['Driver.45'] = df['Driver.45'].replace(replace_map)
df['Driver.46'] = df['Driver.46'].replace(replace_map)
df['Driver.47'] = df['Driver.47'].replace(replace_map)
df['Driver.48'] = df['Driver.48'].replace(replace_map)
df['Driver.49'] = df['Driver.49'].replace(replace_map)
df['Driver.50'] = df['Driver.50'].replace(replace_map)
df['Driver.51'] = df['Driver.51'].replace(replace_map)
df['Driver.52'] = df['Driver.52'].replace(replace_map)
df['Driver.53'] = df['Driver.53'].replace(replace_map)
df['Driver.54'] = df['Driver.54'].replace(replace_map)
df['Driver.55'] = df['Driver.55'].replace(replace_map)
df['Driver.56'] = df['Driver.56'].replace(replace_map)
df['Driver.57'] = df['Driver.57'].replace(replace_map)
df['Driver.58'] = df['Driver.58'].replace(replace_map)
df['Driver.59'] = df['Driver.59'].replace(replace_map)
df['Driver.60'] = df['Driver.60'].replace(replace_map)
df['Driver.61'] = df['Driver.61'].replace(replace_map)
df['Driver.62'] = df['Driver.62'].replace(replace_map)
df['Driver.63'] = df['Driver.63'].replace(replace_map)
df['Driver.64'] = df['Driver.64'].replace(replace_map)
df['Driver.65'] = df['Driver.65'].replace(replace_map)
df['Driver.66'] = df['Driver.66'].replace(replace_map)


# # df.head(10)

# %%
replace_map = {
"Team Penske":1,
"Hendrick Motorsports":2,
"Stewart-Haas Racing":3,
"Richard Childress Racing":4,
"Live Fast Motorsports":5,
"RFK Racing":6,
"Joe Gibbs Racing":7,
"Rick Ware Racing":8,
"Spire Motorsports":9,
"Kaulig Racing":10,
"Trackhouse Racing":11,
"23XI Racing":12,
"Petty GMS Motorsports":13,
"NY Racing Team":14,
"Team Hezeberg":15,
"TMT Racing":16,
"Front Row Motorsports":17,
"Beard Motorsports":18,
"JTG Daugherty Racing":19,
'Wood Brothers Racing':20,
'MBM Motorsports':21,
'Legacy Motor Club':22
}
df['Team'] = df['Team'].replace(replace_map)
df['Team.1'] = df['Team.1'].replace(replace_map)
df['Team.2'] = df['Team.2'].replace(replace_map)
df['Team.3'] = df['Team.3'].replace(replace_map)
df['Team.4'] = df['Team.4'].replace(replace_map)
df['Team.5'] = df['Team.5'].replace(replace_map)
df['Team.6'] = df['Team.6'].replace(replace_map)
df['Team.7'] = df['Team.7'].replace(replace_map)
df['Team.8'] = df['Team.8'].replace(replace_map)
df['Team.9'] = df['Team.9'].replace(replace_map)
df['Team.10'] = df['Team.10'].replace(replace_map)
df['Team.11'] = df['Team.11'].replace(replace_map)
df['Team.12'] = df['Team.12'].replace(replace_map)
df['Team.13'] = df['Team.13'].replace(replace_map)
df['Team.14'] = df['Team.14'].replace(replace_map)
df['Team.15'] = df['Team.15'].replace(replace_map)
df['Team.16'] = df['Team.16'].replace(replace_map)
df['Team.17'] = df['Team.17'].replace(replace_map)
df['Team.18'] = df['Team.18'].replace(replace_map)
df['Team.19'] = df['Team.19'].replace(replace_map)
df['Team.20'] = df['Team.20'].replace(replace_map)
df['Team.21'] = df['Team.21'].replace(replace_map)
df['Team.22'] = df['Team.22'].replace(replace_map)
df['Team.23'] = df['Team.23'].replace(replace_map)
df['Team.24'] = df['Team.24'].replace(replace_map)
df['Team.25'] = df['Team.25'].replace(replace_map)
df['Team.26'] = df['Team.26'].replace(replace_map)
df['Team.27'] = df['Team.27'].replace(replace_map)
df['Team.28'] = df['Team.28'].replace(replace_map)
df['Team.29'] = df['Team.29'].replace(replace_map)
df['Team.30'] = df['Team.30'].replace(replace_map)
df['Team.31'] = df['Team.31'].replace(replace_map)
df['Team.32'] = df['Team.32'].replace(replace_map)
df['Team.33'] = df['Team.33'].replace(replace_map)
df['Team.34'] = df['Team.34'].replace(replace_map)
df['Team.35'] = df['Team.35'].replace(replace_map)
df['Team.36'] = df['Team.36'].replace(replace_map)
df['Team.37'] = df['Team.37'].replace(replace_map)
df['Team.38'] = df['Team.38'].replace(replace_map)
df['Team.39'] = df['Team.39'].replace(replace_map)
df['Team.40'] = df['Team.40'].replace(replace_map)
df['Team.41'] = df['Team.41'].replace(replace_map)
df['Team.42'] = df['Team.42'].replace(replace_map)
df['Team.43'] = df['Team.43'].replace(replace_map)
df['Team.44'] = df['Team.44'].replace(replace_map)
df['Team.45'] = df['Team.45'].replace(replace_map)
df['Team.46'] = df['Team.46'].replace(replace_map)
df['Team.47'] = df['Team.47'].replace(replace_map)
df['Team.48'] = df['Team.48'].replace(replace_map)
df['Team.49'] = df['Team.49'].replace(replace_map)
df['Team.50'] = df['Team.50'].replace(replace_map)
df['Team.51'] = df['Team.51'].replace(replace_map)
df['Team.52'] = df['Team.52'].replace(replace_map)
df['Team.53'] = df['Team.53'].replace(replace_map)
df['Team.54'] = df['Team.54'].replace(replace_map)
df['Team.55'] = df['Team.55'].replace(replace_map)
df['Team.56'] = df['Team.56'].replace(replace_map)
df['Team.57'] = df['Team.57'].replace(replace_map)
df['Team.58'] = df['Team.58'].replace(replace_map)
df['Team.59'] = df['Team.59'].replace(replace_map)
df['Team.60'] = df['Team.60'].replace(replace_map)
df['Team.61'] = df['Team.61'].replace(replace_map)
df['Team.62'] = df['Team.62'].replace(replace_map)
df['Team.63'] = df['Team.63'].replace(replace_map)
df['Team.64'] = df['Team.64'].replace(replace_map)
df['Team.65'] = df['Team.65'].replace(replace_map)
df['Team.66'] = df['Team.66'].replace(replace_map)


# df.head(10)

# %%
# Remove the '#' character from the '#' column
df['#'] = df['#'].str.replace('#', '')
df['#.1'] = df['#.1'].str.replace('#', '')
df['#.2'] = df['#.2'].str.replace('#', '')
df['#.3'] = df['#.3'].str.replace('#', '')
df['#.4'] = df['#.4'].str.replace('#', '')
df['#.5'] = df['#.5'].str.replace('#', '')
df['#.6'] = df['#.6'].str.replace('#', '')
df['#.7'] = df['#.7'].str.replace('#', '')
df['#.8'] = df['#.8'].str.replace('#', '')
df['#.9'] = df['#.9'].str.replace('#', '')
df['#.10'] = df['#.10'].str.replace('#', '')
df['#.11'] = df['#.11'].str.replace('#', '')
df['#.12'] = df['#.12'].str.replace('#', '')
df['#.13'] = df['#.13'].str.replace('#', '')
df['#.14'] = df['#.14'].str.replace('#', '')
df['#.15'] = df['#.15'].str.replace('#', '')
df['#.16'] = df['#.16'].str.replace('#', '')
df['#.17'] = df['#.17'].str.replace('#', '')
df['#.18'] = df['#.18'].str.replace('#', '')
df['#.19'] = df['#.19'].str.replace('#', '')
df['#.20'] = df['#.20'].str.replace('#', '')
df['#.21'] = df['#.21'].str.replace('#', '')
df['#.22'] = df['#.22'].str.replace('#', '')
df['#.23'] = df['#.23'].str.replace('#', '')
df['#.24'] = df['#.24'].str.replace('#', '')
df['#.25'] = df['#.25'].str.replace('#', '')
df['#.26'] = df['#.26'].str.replace('#', '')
df['#.27'] = df['#.27'].str.replace('#', '')
df['#.28'] = df['#.28'].str.replace('#', '')
df['#.29'] = df['#.29'].str.replace('#', '')
df['#.30'] = df['#.30'].str.replace('#', '')
df['#.31'] = df['#.31'].str.replace('#', '')
df['#.32'] = df['#.32'].str.replace('#', '')
df['#.33'] = df['#.33'].str.replace('#', '')
df['#.34'] = df['#.34'].str.replace('#', '')
df['#.35'] = df['#.35'].str.replace('#', '')
df['#.36'] = df['#.36'].str.replace('#', '')
df['#.37'] = df['#.37'].str.replace('#', '')
df['#.38'] = df['#.38'].str.replace('#', '')
df['#.39'] = df['#.39'].str.replace('#', '')
df['#.40'] = df['#.40'].str.replace('#', '')
df['#.41'] = df['#.41'].str.replace('#', '')
df['#.42'] = df['#.42'].str.replace('#', '')
df['#.43'] = df['#.43'].str.replace('#', '')
df['#.44'] = df['#.44'].str.replace('#', '')
df['#.45'] = df['#.45'].str.replace('#', '')
df['#.46'] = df['#.46'].str.replace('#', '')
df['#.47'] = df['#.47'].str.replace('#', '')
df['#.48'] = df['#.48'].str.replace('#', '')
df['#.49'] = df['#.49'].str.replace('#', '')
df['#.50'] = df['#.50'].str.replace('#', '')
df['#.51'] = df['#.51'].str.replace('#', '')
df['#.52'] = df['#.52'].str.replace('#', '')
df['#.53'] = df['#.53'].str.replace('#', '')
df['#.54'] = df['#.54'].str.replace('#', '')
df['#.55'] = df['#.55'].str.replace('#', '')
df['#.56'] = df['#.56'].str.replace('#', '')
df['#.57'] = df['#.57'].str.replace('#', '')
df['#.58'] = df['#.58'].str.replace('#', '')
df['#.59'] = df['#.59'].str.replace('#', '')
df['#.60'] = df['#.60'].str.replace('#', '')
df['#.61'] = df['#.61'].str.replace('#', '')
df['#.62'] = df['#.62'].str.replace('#', '')
df['#.63'] = df['#.63'].str.replace('#', '')
df['#.64'] = df['#.64'].str.replace('#', '')
df['#.65'] = df['#.65'].str.replace('#', '')
df['#.66'] = df['#.66'].str.replace('#', '')

df.head(10)
# Out:
#    Year  Finish  Start   #  Driver  Make  Pts  Laps  Led  Status  ...  \
# 0  2022       1      5   2       3     1   45   201   21       1  ...
# 1  2022       2     16  23      16     2   43   201   12       1  ...
# 2  2022       3      9  14       7     1   34   201    0       1  ...
# 3  2022       4      7  12      32     1   33   201   36       1  ...
# 4  2022       5     38  10       2     1   32   201    0       1  ...
# 5  2022       6     10  18      25     2   31   201   28       1  ...
# 6  2022       7      6  34      29     1   30   201    0       1  ...
# 7  2022       8     34  15      17     1   29   201    0       1  ...
# 8  2022       9      3   6       6     1   44   201   67       1  ...
# 9  2022      10     11   9       8     3   28   201    0       1  ...
#
#    Status.66  Team.66  S1.66  S2.66  S3.66  Rating.66  top_3.66  top_5.66  \
# 0          1        2    4.0    NaN    NaN       97.9         1         1
# ...

# %%
# Replace NaN in column 'A' with 0
# df['A'].fillna(0, inplace=True)

# If you want to replace NaN in all columns, simply do:
df.fillna(0, inplace=True)
# print(df['top_3'].head())
# print(df['Year'].value_counts())


# Set the display max columns to a large number
pd.set_option('display.max_columns', None)

# Print all column names
# print(list(df.columns))





# df.head(10)

# %%
X = df.drop(columns=['top_10.66', 'top_5.66', 'top_3.66', 'Laps.66', 'Led.66', '#.66', 'Finish.66', 'Rating.66', 'S1.66', 'S2.66', 'Start.66', 'Status.66', 'Pts.66', 'Track'])
y = df['top_10.66']
X
# Out:
#     Year  Finish  Start     #  Driver  Make  Pts  Laps  Led  Status  Team  \
# 0   2022       1      5   2.0       3     1   45   201   21       1     1
# 1   2022       2     16  23.0      16     2   43   201   12       1    12
# 2   2022       3      9  14.0       7     1   34   201    0       1     3
# 3   2022       4      7  12.0      32     1   33   201   36       1     1
# 4   2022       5     38  10.0       2     1   32   201    0       1     3
# 5   2022       6     10  18.0      25     2   31   201   28       1     7
# 6   2022       7      6  34.0      29     1   30   201    0       1    17
# 7   2022       8     34  15.0      17     1   29   201    0       1     8
# 8   2022       9      3   6.0       6     1   44   201   67       1     6
# 9   2022      10     11   9.0       8     3   28   201    0       1     2
# 10  2022      11     26  42.0      35     3   26   201    0       1    13
# 11  2022      12     33  16.0      14     3    0   201    0       1    10
# ...

# %%
# iso_forest = IsolationForest(contamination=0.01, random_state=20)

# iso_forest.fit(X)

# anomaly_predictions = iso_forest.predict(X)

# anomaly_mask = anomaly_predictions == -1

# x_clean = X[~anomaly_mask]
# y_clean = y[~anomaly_mask]

# %%
# X_train, X_test, y_train, y_test = train_test_split(x_clean, y_clean, test_size = 0.7, random_state=78)

# %%
# ocsvm_model = OneClassSVM(nu=0.05)

# ocsvm_model.fit(X)

# anomaly_predictions = ocsvm_model.predict(X)

# anomaly_mask = anomaly_predictions == -1

# x_clean = X[~anomaly_mask]
# y_clean = y[~anomaly_mask]

# %%
# print(y_clean.value_counts())

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.7, random_state=78)

# %%
# Define the desired number of samples for each class
# desired_samples_per_class = 100

# # Calculate the number of samples to generate for each class
# count_0 = len(y[y == 0.0])
# count_1 = len(y[y == 1.0])

# # Determine how many samples to generate for each class to reach the desired count
# to_generate_0 = desired_samples_per_class - count_0
# to_generate_1 = desired_samples_per_class - count_1

# # Set the sampling strategy
# sampling_strategy = {0.0: count_0 + to_generate_0, 
#                      1.0: count_1 + to_generate_1}

# smote = BorderlineSMOTE(sampling_strategy=sampling_strategy, random_state=20)
# X_resampled, y_resampled = smote.fit_resample(X, y)

# %%
# X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, test_size=0.7, random_state=78)

# %%
# smote = SMOTE(sampling_strategy='auto', random_state=78, k_neighbors=7)
# X_resampled, y_resampled = smote.fit_resample(X, y)




# X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, test_size=0.7, random_state=78)

# %%
rf_model = RandomForestClassifier(n_estimators=50, max_depth=10, random_state=20, class_weight='balanced')

# %%
# Train the model on the training data
rf_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(class_weight='balanced', max_depth=10, n_estimators=50,
#                        random_state=20)

# %%
# Make predictions on the test data
y_pred = rf_model.predict(X_test)

# %%
# Get predicted probabilities for the positive class ('Pro_Bowl')
y_probabilities = rf_model.predict_proba(X_test)[:, 1]  # Probability of 'Pro_Bowl'

# Adjust the threshold (e.g., set it to 0.15 for higher precision)
custom_threshold = 0.5
y_custom_pred = (y_probabilities > custom_threshold).astype(int)  # Convert to 0 or 1

# %%
# Generate a classification report
report = classification_report(y_test, y_custom_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.83      0.91        18
#          1.0       0.70      1.00      0.82         7
#
#     accuracy                           0.88        25
#    macro avg       0.85      0.92      0.87        25
# weighted avg       0.92      0.88      0.89        25

# %%
# test_sample = {
#     'Driver.30': 42,
#     'Make.30': 3,
#     'Team.30': 2,
#     'S3.30': 0,
#     'Track.30': 25,

# }

# test_df = pd.DataFrame([test_sample])
# test_df

# %%
cm = confusion_matrix(y_test, y_custom_pred)

true_labels = ["Actual=No", "Actual=Yes"]
predicted_labels = ["Predicted=No", "Predicted=Yes"]

disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=rf_model.classes_)
disp.plot()
plt.title('Top 10 Nascar Predictor')
plt.xticks(np.arange(len(predicted_labels)), predicted_labels)
plt.yticks(np.arange(len(true_labels)), true_labels)
plt.show()

# %%
rmse = mean_squared_error(y_test, y_custom_pred, squared=False)
rmse
# Out:
# 0.34641016151377546

# %%
# # Assuming you have a driver's encoded value:
# driver_encoded_value = 42  # replace with the specific driver's encoded value

# # Extract the driver's data from the dataframe
# driver_data = df[df['Driver'] == driver_encoded_value].iloc[0].copy()

# # Suppose you have the 66th race values in a dictionary like:
# race_66_values = {
#     'Driver.66': 42,  # just an example
#     'Make.66': 3,
#     'Team': 2,
#     'S3':0,
#     'Track':25
#     # another example
#     # ... other columns and their values
# }

# # Update the driver's data with the 66th race values:
# # for column, value in race_66_values.items():
# #     driver_data[column] = value

# # Predict using the model:
# test_df = pd.DataFrame([driver_data.drop('top_10.66', axis=1)])  # Assuming you're predicting top_10 for 66th race
# prediction = rf_model.predict(test_df)

# print(prediction)

# %%
# # Identify columns related to the 30th race and separate them
# columns_30th_race = ['Driver.30', 'Make.30', 'Team.30', 'S3.30', 'Track.30', 'Status.30', 'top_10.30', 'top_5.30', 'top_3.30']
# test_30th_race = df[columns_30th_race]

# # Separate features (X) and target (y) for 30th race
# X_test_30th = test_30th_race.drop('top_10.30', axis=1)
# y_test_30th = test_30th_race['top_10.30']

# # Add any missing columns with dummy values
# # Note: If your model was trained on certain columns from earlier races, 
# # they should be added here with dummy values.

# missing_columns = ['top_5.30', 'top_3.30', 'Status.30', 'S1.30', 'S2.30', 'Rating.30', 'Led.30', 'Laps.30', 'Pts.30', 'Finish.30', '#.30']  # List any missing columns here, if applicable.

# for col in missing_columns:
#     X_test_30th[col] = 0  # Setting dummy values

# %%
df['#'] = df['#'].astype(float)  # Convert to float

# Find rows with extremely large values in the '#' column
problematic_rows = df[df['#'] > 1e50]

# %%
# Define the specific data for race 66 you want to predict
data_for_prediction = {
    'Driver.66': 37,
    'Make.66': 2,
    'Team.66': 7,
    'S3.66': 0,
    'Track.66': 25,
    'Start': 10
}

# Convert it into a DataFrame
data_for_prediction_df = pd.DataFrame([data_for_prediction])

# Get the list of features the model was trained on
trained_features = rf_model.feature_names_in_

# Create a blank DataFrame with the trained features
prediction_df = pd.DataFrame(columns=trained_features)

# Append your data to the blank DataFrame
prediction_df = prediction_df.append(data_for_prediction_df, ignore_index=True)

# Fill any missing features with the mean of your original dataset
# Fill any missing features with the mean of your original dataset
for column in prediction_df.columns:
    if pd.isnull(prediction_df[column]).all():
        column_name = column.split('.')[0]
        
        # Calculate the mean value for the specific feature from the original dataset
        mean_value = df[column_name].mean()
        
        # Check for and handle problematic values
        if not np.isfinite(mean_value) or np.abs(mean_value) > np.finfo('float32').max:
            print(f"Problematic value in column '{column_name}': {mean_value}")
        
        # Fill the missing values in prediction_df with the mean value
        prediction_df[column] = mean_value



        # Predict using the model
predicted_top_10 = rf_model.predict(prediction_df)

print(predicted_top_10[0])  # This will print 1 or 0, indicating if the driver is predicted to be in top 10 or not.
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[100], line 42
#      37         prediction_df[column] = mean_value
#      41         # Predict using the model
# ---> 42 predicted_top_10 = rf_model.predict(prediction_df)
#      44 print(predicted_top_10[0])
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:820, in ForestClassifier.predict(self, X)
#     799 def predict(self, X):
#     800     """
#     801     Predict class for X.
#     802
#    (...)
#     818         The predicted classes.
#     819     """
# --> 820     proba = self.predict_proba(X)
#     822     if self.n_outputs_ == 1:
#     823         return self.classes_.take(np.argmax(proba, axis=1), axis=0)
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:862, in ForestClassifier.predict_proba(self, X)
#     860 check_is_fitted(self)
# ...

# %%
# df['#'] = df['#'].astype(float)  # Convert to float

# # Find rows with extremely large values in the '#' column
# problematic_rows = df[df['#'] > 1e50]
# print(problematic_rows)

# %%
# Assuming you already have a dataframe 'df'

# Define the driver's encoded value:
# driver_encoded_value = '42'  # replace with the specific driver's name

# # Extract driver's data:
# driver_data = {}
# for race_num in range(66):  # Races 0 to 65
#     driver_column_name = f'Driver.{race_num}' if race_num != 0 else 'Driver'
    
    # Extracting data for the specific driver for the race_num
#     filtered_race_data = df[df[driver_column_name] == driver_encoded_value]
    
#     # Check if the driver's data for this race exists
#     if not filtered_race_data.empty:
#         race_data = filtered_race_data.iloc[0]
        
#         # Add this race's data to driver_data
#         for column in df.columns:
#             if f'.{race_num}' in column or race_num == 0:
#                 driver_data[column] = race_data[column]

# # Partial data for the 66th race:
# race_66_values = {
#     'Driver.66': 42,
#     'Make.66': 3,
#     'Team.66': 2,   
#     'S3.66': 0,
#     'Track.66': 25
#     # ... other columns and their values, but don't include columns like Laps.66, Status.66, etc.
# }


# # Update driver's data with the 66th race values:
# driver_data.update(race_66_values)
# print(driver_data)

# %%
# # Assuming you have a driver's encoded value:
# driver_encoded_value = 42  # replace with the specific driver's encoded value

# # Create a dictionary to hold the driver's data
# driver_data = {}

# # Loop through each "Driver" column to extract the data for the specific driver
# for i in range(66):  # 0 to 65
#     column_name = f'Driver.{i}' if i != 0 else 'Driver'
    
#     filtered_df = df[df[column_name] == driver_encoded_value]
    
#     if not filtered_df.empty:
#         # This ensures you're getting just the value and not the entire series
#         driver_data[column_name] = filtered_df[column_name].iloc[0]
#     else:
#         print(f"No data found for Driver with encoded value {driver_encoded_value} in {column_name}")

# # Suppose you have the 66th race values in a dictionary (you don't need the columns you dropped during training here):
# race_66_values = {
#     'Driver.66': 42,
#     'Make.66': 3,
#     'Team.66': 2,   
#     'S3.66': 0,
#     'Track.66': 25
#     # ... other columns and their values, but don't include columns like Laps.66, Status.66, etc.
# }

# # Update the driver's data with the 66th race values:
# for column, value in race_66_values.items():
#     driver_data[column] = value

# # ... [Your previous code before converting to test_df]

# # Convert driver_data to DataFrame
# test_df = pd.DataFrame([driver_data])

# # Ensure the columns in test_df are aligned with the training data
# # 1. Add missing columns from training data to test_df and set them to default values
# for col in X.columns:
#     if col not in test_df.columns:
#         test_df[col] = 0

# # 2. Drop any extra columns from test_df that were not in the training data
# test_df = test_df[X.columns]

# # Predict using the model
# prediction = rf_model.predict(test_df)
# print(prediction)

# %%
print(type(test_df))
print(test_df.shape)
print(test_df.columns)

# %%
for col in test_df.columns:
    val = test_df[col].iloc[0]
    if not (np.isscalar(val) or isinstance(val, (str, np.ndarray))):
        print(f"Column {col} contains unexpected type: {type(val)}")

# %%
# X_test_30th = test_30th_race.drop('top_10.30', axis=1)
# y_test_30th = test_30th_race['top_10.30']
# missing_columns = ['#'] + [f'#.{i}' for i in range(1, 31)]
# for col in missing_columns:
#     X_test_30th[col] = 0  # Adding dummy value 0

# missing_columns = ['Driver'] + [f'Driver.{i}' for i in range(1, 31)]
# for col in missing_columns:
#     X_test_30th[col] = 0
#     missing_columns = ['Finish'] + [f'Finish.{i}' for i in range(1, 31)]
# for col in missing_columns:
#     X_test_30th[col] = 0
#     missing_columns = ['#'] + [f'#.{i}' for i in range(1, 31)]
# for col in missing_columns:
#     X_test_30th[col] = 0

# %%
# predictions_30th = rf_model.predict(X_test_30th)

# %%
# accuracy = accuracy_score(y_test_30th, predictions_30th)
# print(f"Accuracy for the 30th race: {accuracy*100:.2f}%")

# # You can also check other metrics, like:
# print(confusion_matrix(y_test_30th, predictions_30th))
# print(classification_report(y_test_30th, predictions_30th))

# %%
# # Assuming you've already split your original dataset into training and testing (and hence have X_train):
# # Ensure that the test data columns match the training data columns
# train_columns = X_train.columns.tolist()

# # Reorder the columns of your test data to match the training data
# X_test_30th = X_test_30th[train_columns]

# # Check if any columns are missing in the test data
# missing_columns = [col for col in train_columns if col not in X_test_30th.columns]

# # If there are any missing columns, add them with dummy values
# for col in missing_columns:
#     X_test_30th[col] = 0

# # Now, use the model to predict
# predictions_30th = rf_model.predict(X_test_30th)
# predictions_30th

# %%
# Load model (if not already done)
# rf_model = joblib.load("path_to_saved_model.pkl")


# # Display predictions alongside drivers
# results_30th_race = pd.DataFrame({
#     'Driver': X_test_30th['Driver.30'],
#     'Prediction': predictions_30th
# })

# print(results_30th_race)
